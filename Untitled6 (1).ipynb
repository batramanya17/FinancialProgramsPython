# %%
 #ManyaBatra 1253478(1)
import pandas as pd
import matplotlib.pyplot as plt
df   = pd.read_csv('/content/balancesheet.csv', parse_dates=['Year'])
df.sort_values('Year', inplace=True)
plt.plot(df['Year'], df['Total Assets'],
         marker='o', color='teal')
plt.title('Manyabatra-12513478 Infosys – Total Assets')
plt.xlabel('Year')
plt.ylabel('Total Assets (₹ Cr)')
plt.xticks(rotation=45)
plt.show()

# %%
#ManyaBatra 12513478(2)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
sns.regplot(x='Borrowings', y='Total Assets', data=df,color='teal')
plt.title('Manyabatra-12513478 Borrowings vs Total Assets')
plt.xlabel('Borrowings(₹ Cr)')
plt.ylabel('Total Assets(₹ Cr)')
plt.show()

# %%
#ManyaBatra 12513478(3)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH = '/content/balancesheet.csv'
df   = pd.read_csv(PATH, parse_dates=['Year'])

sns.histplot(df['Reserves'], kde=True,
             color='steelblue', bins=8)
plt.title('ManyaBatra 12513478- Distribution of Reserves')
plt.xlabel('Reserves (₹ Cr)')
plt.ylabel('Frequency')
plt.show()

# %%
#ManyaBatra 12513478(4)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
cols=['FixedAssets','Investments']
df_m=df[cols].melt(var_name='Type',value_name='Value')
sns.boxplot(x='Type',y='Value',data=df_m,palette='Set2')
plt.title('Manyaabtra-12513478 FixedAssets vs Investments')
plt.show()
# Out:
# /tmp/ipykernel_11287/683829507.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Type',y='Value',data=df_m,palette='Set2')

# %%
#MayaBatra 12513478(5)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
df['TAD_Label']=df['TAD'].map({0:'Low Deploy',1:'High Deploy'})
sns.countplot(x='TAD_Label',data=df,palette='coolwarm')
plt.title('ManyaBatra-12513478 Assets Deployment Category Count')
plt.ylabel('Number of Years')
plt.show()
# Out:
# /tmp/ipykernel_11287/116376639.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='TAD_Label',data=df,palette='coolwarm')

# %%
#ManyaBatra 12513478(6)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
x= np.arange(len(df))
plt.bar(x-0.2,df['EquityCapital'],width=0.4,label='Equity ')
plt.bar(x+0.2,df['Reserves'],width=0.4,label='Reserves ')
plt.xticks(x,df['Year'].dt.year,rotation=45)
plt.title('Manya Batra 12513489-Equity Capital vs Reserves')
plt.legend();plt.tight_layout()
plt.show()

# %%
#Manyaabtra-12513478(7)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
cols=['FixedAssets','Investments','Borrowings','Reserves','Total Assets']
sns.heatmap(df[cols].corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Manyabatra-12513478Tata Steel-Correlation Heatmap')
plt.show()

# %%
#ManyaBatra 12513478(8)
import pandas as pd
import matplotlib.pyplot as plt
PATH = '/content/balancesheet.csv'
df   = pd.read_csv(PATH, parse_dates=['Year'])
# Select the last row that has no NaN values in the specified labels
latest = df.dropna(subset=['FixedAssets','CWIP','Investments']).iloc[-1]
labels = ['FixedAssets','CWIP',
          'Investments']
values = [latest[l] for l in labels]
plt.pie(values, labels=labels,
        autopct='%1.1f%%', startangle=140)
plt.title(f'Manya Batra 12513478-Asset Mix – {latest["Year"].year}')
plt.show()

# %%
#Manyaabtra-12513478(9)
# import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
PATH='/content/balancesheet.csv'
df=pd.read_csv(PATH,parse_dates=['Year'])
df['TAD']=df['TAD'].astype(str)
sns.lmplot(x='Borrowings',y='TotalLiabilities',data=df,hue='TAD',palette='Set1')
plt.title('Manyabatra-12513478 Borrowings vs TotalLiabilities')
plt.show()

# %%
#ManyaBatra 12513478(10)
import pandas as pd
import numpy as np
PATH = '/content/balancesheet.csv'
df   = pd.read_csv(PATH, parse_dates=['Year'])

x = df['Borrowings'].values
y = df['Total Assets'].values
r = np.corrcoef(x, y)[0, 1]

if r > 0.7:
    print('Debt-driven growth – REVIEW leverage')
elif r > 0.4:
    print('Moderate link – MONITOR borrowings')
else:
    print('Healthy – assets not debt-dependent')
print(f'Correlation = {r:.3f}')
# Out:
# Healthy – assets not debt-dependent
# Correlation = nan
